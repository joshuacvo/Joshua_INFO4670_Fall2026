# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** Joshua Vo    **Date:** 9/6/2026
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Northgate house style (optional, but keeps your charts consistent)
NAVY = "#22303A"
RUST = "#C0562F"
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]   = (8, 5)
plt.rcParams["axes.titlesize"]   = 13
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.

DATA_DIR = "."   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"

import os
students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly   = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# 1                   9.5      2023-10-19            0
# 2                  19.1      11/16/2022            0
# 3                   8.1      2024-05-03            0
# 4                   6.6      10/24/2022            0

# %%
# how many rows, which columns, what types?
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            2027 non-null   object
#  1   major                 2027 non-null   object
#  2   age                   2027 non-null   int64
#  3   housing               2027 non-null   object
#  4   commute_miles         2027 non-null   float64
#  5   work_hours_per_week   2027 non-null   int64
#  6   advisor_meetings      2027 non-null   int64
#  7   credits_attempted     2027 non-null   int64
#  8   final_gpa             2027 non-null   float64
#  9   study_hours_reported  1772 non-null   float64
#  10  enrollment_date       2027 non-null   object
#  11  dropped_out           2027 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 190.2+ KB

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()
sns.histplot(data=students, x="work_hours_per_week", color=NAVY, ax=ax)
ax.set_title("Weekly Work Hours for Northgate Students")
ax.set_xlabel("Work hours per week")
ax.set_ylabel("Number of students")
plt.show()

# %% [markdown]
# **STAR story — Q1** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# This histogram shows the distribution of weekly work hours for Northgate Students. The goal is to determine how many hours students typically work each week, how spread out their work schedules are, and whether any values stand apart. Most students work between about 10-25 hours/week, with largest concentrations around 15-20 hours. The distribution is fairly spread out, with smaller groups working 30-40 hours/week. One value near -10 hours appears as an outlier, which is also unrealistic for weekly work hours. This record should be looked at as a data quality issue.

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
order = students["major"].value_counts().index

fig, ax = plt.subplots()
sns.countplot(data=students, y="major", order=order, color=NAVY, ax=ax)
ax.set_title("Number of Students by Major")
ax.set_xlabel("Number of students")
ax.set_ylabel("Major")
plt.show()

# %% [markdown]
# **STAR story — Q2** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# This bar chart shows the number of Northgate students in each recorded major. The goal is to compare enrollment across majors and identify which majors contain the most and fewest students. Cybersecurity has the largest number of students, followed by Data Science, Information Science, and Information Technology. However, several majors appear more than once under slightly different names, such as “Cybersecurity” and “Cyber Security,” indicating inconsistent category labels. The duplicate-looking major labels should be reviewed and standardized before making final comparisons between majors. Otherwise, students from the same major may be split across multiple categories and the counts may be misleading.

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots(figsize=(10, 6))

sns.boxplot(
    data=students,
    x="final_gpa",
    y="major",
    color=NAVY,
    ax=ax
)

ax.set_title("Final GPA by Major")
ax.set_xlabel("Final GPA")
ax.set_ylabel("Major")

plt.show()

# %% [markdown]
# **STAR story — Q3** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# These box plots compare the distribution of final GPA across the different recorded majors at Northgate. The goal is to determine whether GPA distributions differ noticeably between majors. The median GPAs are fairly similar across most majors, generally around the low-to-mid 2s, and the interquartile ranges overlap considerably. This suggests that no major has a clearly different GPA distribution from the others. Several majors also contain unusually low values, including multiple GPAs recorded as 0.00.
# The 0.00 GPA values appear across several majors rather than being concentrated in one area, so they should be investigated as a broader data-quality issue before drawing stronger conclusions about academic performance by major.

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.regplot(
    data=students,
    x="commute_miles",
    y="final_gpa",
    scatter_kws={"alpha": 0.4},
    line_kws={"color": RUST},
    ax=ax
)

ax.set_title("Commute Distance and Final GPA")
ax.set_xlabel("Commute distance (miles)")
ax.set_ylabel("Final GPA")

plt.show()

# %% [markdown]
# **STAR story — Q4** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# This scatterplot shows the relationship between students’ commute distance in miles and their final GPA. The goal is to determine whether students with longer commutes tend to have different GPAs than students with shorter commutes. The trend line slopes downward, showing a negative association between commute distance and final GPA. Students with longer commutes generally tend to have lower GPAs, although the points are widely scattered, so the relationship is not especially strong. A group of students with GPAs recorded as 0.00 also appears across many commute distances. The pattern suggests that commute distance may be related to GPA, but the chart does not show that longer commutes cause lower grades. Other factors could influence both variables, and the 0.00 GPA records should also be investigated separately before drawing stronger conclusions.

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
weekly_avg = weekly.groupby("week")["minutes_active"].mean().reset_index()

fig, ax = plt.subplots()

sns.lineplot(
    data=weekly_avg,
    x="week",
    y="minutes_active",
    marker="o",
    color=NAVY,
    ax=ax
)

ax.set_title("Average Student Activity by Week")
ax.set_xlabel("Week")
ax.set_ylabel("Average minutes active")

plt.show()

# %% [markdown]
# **STAR story — Q5** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# This line chart shows the average number of active minutes for Northgate students during each week of the semester. The goal is to see how student activity changes over time and identify any unusual weeks. Average activity remains very consistent at about 210 minutes per week for most of the semester. Week 9 stands out sharply, dropping to around 90 minutes before returning to the previous level in week 10. Because the decline occurs for only one week and activity immediately rebounds, week 9 should be investigated for a possible holiday, campus closure, system issue, or other event that affected activity across many students.

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** \_\_\_\_\_\_\_\_

# %% [markdown]
# "How is student age distributed at Northgate, and are there any unusual age values?"

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()

sns.violinplot(
    data=students,
    x="age",
    color=NAVY,
    ax=ax
)

ax.set_title("Distribution of Student Age at Northgate")
ax.set_xlabel("Age (years)")
ax.set_ylabel("")

plt.show()

# %% [markdown]
# **STAR story — Part B** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# This violin plot shows the distribution of ages for Northgate students. The goal is to see the typical age range of students and identify any unusual age values. Most student ages are concentrated in a relatively narrow range around the 20s, with the widest part of the violin occurring there. However, the plot also contains extreme values far outside a realistic student age range. Ages such as negative values and values above 200 are likely data-quality problems and should be investigated before age is used in further analysis. These extreme values also stretch the axis and make the normal age distribution harder to interpret.

# %% [markdown]
# # Before you submit — checklist
# - [ ] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [ ] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [ ] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [ ] Part B question is written in and answered.
# - [ ] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
